# %%
d={}
d1=dict()
d2={'name':'Codegnan','branch':'hyderabad','batch':'PFS66','no_students':51}
print(type(d),type(d1),type(d2))
# Out:
# <class 'dict'> <class 'dict'> <class 'dict'>

# %%
d2={'name':'Codegnan','branch':'hyderabad','batch':'PFS66','no_students':51}
print(d2)
d2.update({'key':'value'})
print("printing updated dictionary:",d2)
d2.pop('key')
print("key value is deleted and printing  dictionary:",d2)
d2.popitem()#removes last key and vale
print("last value & key  is deleted while using(popitem())",d2)
print(d2.keys())#it can print keys.
print(d2.values())#it can print values.
print(d2.items())#it can print dictionay as list.
# Out:
# {'name': 'Codegnan', 'branch': 'hyderabad', 'batch': 'PFS66', 'no_students': 51}
# printing updated dictionary: {'name': 'Codegnan', 'branch': 'hyderabad', 'batch': 'PFS66', 'no_students': 51, 'key': 'value'}
# key value is deleted and printing  dictionary: {'name': 'Codegnan', 'branch': 'hyderabad', 'batch': 'PFS66', 'no_students': 51}
# last value & key  is deleted while using(popitem()) {'name': 'Codegnan', 'branch': 'hyderabad', 'batch': 'PFS66'}
# dict_keys(['name', 'branch', 'batch'])
# dict_values(['Codegnan', 'hyderabad', 'PFS66'])
# dict_items([('name', 'Codegnan'), ('branch', 'hyderabad'), ('batch', 'PFS66')])

# %%
#Packing and Unpacking
#Packing
t= 1,2,3,4
print(t)
#Unpacking
print(*t)
#Negation
print(~-1)

print(~-2)
# Out:
# (1, 2, 3, 4)
# 1 2 3 4
# 0
# 1

# %%
# sets.
s = set()
s1 = {}
print(type(s), type(s1))
print(s,s1)
s.add(10)
print("element 10 is added to set(S):",s)
s.update([20,30,40])
print("set is updated :",s)
s.remove(20)
print("removing element 20 from set:",s)
# Out:
# <class 'set'> <class 'dict'>
# set() {}
# element 10 is added to set(S): {10}
# set is updated : {40, 10, 20, 30}
# removing element 20 from set: {40, 10, 30}

# %%
s.discard(300)# if element wii have it will remove other wise it will ignore. it does not show error.
print("discard method:if element wii have it will remove other wise it will ignore. it does not show error.")
print (s)
print(s.pop())#removes element.
s.clear()#remove values in the set.
print(s)
del s1 #delete est permently
# Out:
# discard method:if element wii have it will remove other wise it will ignore. it does not show error.
# {40, 10, 30}
# 40
# set()

# %%
#Set Operations.
s1={10,20,30,40}
s2={45,55,10,5}
print("printing s1 union s2:",s1.union(s2))
print(s1 | s2)
print(s1.intersection(s2))
print(s1 & s2)
print(s1.difference(s2))
print(s1-s2)
print(s2.difference(s1))
print(s2-s1)
print(s1.symmetric_difference(s2))
print(s1^s2)
# Out:
# printing s1 union s2: {5, 40, 10, 45, 20, 55, 30}
# {5, 40, 10, 45, 20, 55, 30}
# {10}
# {10}
# {40, 20, 30}
# {40, 20, 30}
# {45, 5, 55}
# {45, 5, 55}
# {5, 40, 45, 20, 55, 30}
# {5, 40, 45, 20, 55, 30}

# %%
#Frozen Set
s=frozenset([10,20,30])
print(s)
s1={12,2,4,6}
s2={4,6}
print(s1.issubset(s2))
print(s2.issubset(s1))
print(s1.issuperset(s2))
print(s2.issuperset(s1))
# Out:
# frozenset({10, 20, 30})
# False
# True
# True
# False
