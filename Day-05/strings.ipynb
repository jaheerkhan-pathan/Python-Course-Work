# %%
s1 = "python47265@##$"
s = input()
print(type(s),type(s1))
# Out:
#  54623
# <class 'str'> <class 'str'>

# %%
s = "python programming"
print(s[3:10])
print(s[3:10:2])
print(s[:11])
print(s[6:])
print(s[::-1])
# Out:
# hon pro
# hnpo
# python prog
#  programming
# gnimmargorp nohtyp

# %%
# string operations
s1 = "student"
s2 = "khan"
print(s1+s2) #string concatenation
print(s1*4)
print('a'<'b')
# Out:
# studentkhan
# studentstudentstudentstudent
# True

# %%
s1 = "stuDeNt are GOod"
print(s1.lower())
print(s1.upper())
print(s1.capitalize())
print(s1.title())
print(s1.swapcase())
# Out:
# student are good
# STUDENT ARE GOOD
# Student are good
# Student Are Good
# STUdEnT ARE goOD

# %%
s1 = "stuDeNt are GOod"
print(s1.islower())
print(s1.isupper())
print(s1.isalnum())
print(s1.isalpha())
print(s1.isdigit())
print(s1.isspace())
print(" ".isspace())
# Out:
# False
# False
# False
# False
# False
# False
# True

# %%
s1 = "stuDeNt are GOod"
print(list(s1))
print(s1.split())
print(''.join(s1.split()))
# Out:
# ['s', 't', 'u', 'D', 'e', 'N', 't', ' ', 'a', 'r', 'e', ' ', 'G', 'O', 'o', 'd']
# ['stuDeNt', 'are', 'GOod']
# stuDeNtareGOod

# %%
# strip
s = "      python           "
print(s.strip())
print(s.rstrip())
print(s.lstrip())
# Out:
# python
#       python
# python

# %%
s = "i love python"
print(s.replace("python","DSA"))
print(s)
# Out:
# i love DSA
# i love python
