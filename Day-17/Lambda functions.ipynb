# %%
# Filter()
numbers=[1,2,3,4,5,6]
res=filter(lambda x: str(x), numbers)
print(res)
numbers=[1,2,3,4,5,6]
res=filter(lambda x: str(x), numbers)
print(res)
print(list(res))
numbers=[1,2,3,4,5,6]
res=filter(lambda x: x%2==0, numbers)
print(res)
print(list(res))
# Out:
# <filter object at 0x0000029D26EFD270>
# <filter object at 0x0000029D2839E920>
# [1, 2, 3, 4, 5, 6]
# <filter object at 0x0000029D26EFD270>
# [2, 4, 6]

# %%
# Greater element
greater= lambda a,b: a if a>b else b
print(greater(70,28))
# Out:
# 70

# %%
# reduce()
from functools import reduce
numbers=[1,2,3,4,5]
res=reduce(lambda a,b: a+b,numbers)
print(res)
# Out:
# 15

# %%
square=lambda x: x*x
print(square(20))
# Out:
# 400
